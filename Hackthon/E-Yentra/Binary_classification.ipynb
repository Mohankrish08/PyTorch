# %% [markdown]
# # Importing libraries

# %%
import torch
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm_notebook as tqdm

# %% [markdown]
# # PyTorch

# %%
from torch import nn
import torchvision
from torch.utils.data import DataLoader
from torchvision.transforms import ToTensor, Compose
from torchsummary import summary

# %% [markdown]
# # Sklearn

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score

# %% [markdown]
# # Device

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
device
# Out:
# 'cuda'

# %% [markdown]
# # Helper functions

# %%
object = []
def object_identifier(dataset):
    for name, dtypes in dataset.dtypes.items():
        if dtypes == 'object':
            object.append(name)
    return object

# %%
label = LabelEncoder()
def label_encoder(dataset, object):
    for i in object:
        dataset[i] = label.fit_transform(dataset[i])
    return dataset

# %%
def unique_identifier(dataset):
    for i in dataset:
        unique = dataset[i].unique()
        print(f'{i}: {unique}, Length: {len(unique)}')

# %% [markdown]
# # Data

# %%
data = pd.read_csv('task_1a_dataset.csv')

# %%
data.head()
# Out:
#    Education  JoiningYear       City  PaymentTier  Age Gender EverBenched  \
# 0  Bachelors         2012  Bangalore            3   37   Male          No
# 1    Masters         2017  New Delhi            2   28   Male          No
# 2  Bachelors         2017  New Delhi            2   36   Male          No
# 3  Bachelors         2015  Bangalore            3   27   Male         Yes
# 4  Bachelors         2017  Bangalore            3   29   Male          No
#
#    ExperienceInCurrentDomain  LeaveOrNot
# 0                          0           0
# 1                          4           0
# 2                          3           0
# 3                          5           0
# 4                          4           0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4633 entries, 0 to 4632
# Data columns (total 9 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Education                  4633 non-null   object
#  1   JoiningYear                4633 non-null   int64
#  2   City                       4633 non-null   object
#  3   PaymentTier                4633 non-null   int64
#  4   Age                        4633 non-null   int64
#  5   Gender                     4633 non-null   object
#  6   EverBenched                4633 non-null   object
#  7   ExperienceInCurrentDomain  4633 non-null   int64
#  8   LeaveOrNot                 4633 non-null   int64
# dtypes: int64(5), object(4)
# memory usage: 325.9+ KB

# %%
data.describe()
# Out:
#        JoiningYear  PaymentTier          Age  ExperienceInCurrentDomain  \
# count  4633.000000  4633.000000  4633.000000                4633.000000
# mean   2015.061731     2.698468    29.385711                   2.908483
# std       1.864144     0.560995     4.821685                   1.557005
# min    2012.000000     1.000000    22.000000                   0.000000
# 25%    2013.000000     3.000000    26.000000                   2.000000
# 50%    2015.000000     3.000000    28.000000                   3.000000
# 75%    2017.000000     3.000000    32.000000                   4.000000
# max    2018.000000     3.000000    41.000000                   7.000000
#
#         LeaveOrNot
# count  4633.000000
# mean      0.343622
# std       0.474968
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       1.000000
# max       1.000000

# %%
data.isna().sum()
# Out:
# Education                    0
# JoiningYear                  0
# City                         0
# PaymentTier                  0
# Age                          0
# Gender                       0
# EverBenched                  0
# ExperienceInCurrentDomain    0
# LeaveOrNot                   0
# dtype: int64

# %%
# Object calling function 
object_identifier(data)
# Out:
# ['Education', 'City', 'Gender', 'EverBenched']

# %%
# Label encoding
label_encoder(data, object)
# Out:
#       Education  JoiningYear  City  PaymentTier  Age  Gender  EverBenched  \
# 0             0         2012     0            3   37       1            0
# 1             1         2017     1            2   28       1            0
# 2             0         2017     1            2   36       1            0
# 3             0         2015     0            3   27       1            1
# 4             0         2017     0            3   29       1            0
# ...         ...          ...   ...          ...  ...     ...          ...
# 4628          0         2013     0            3   26       0            0
# 4629          1         2013     2            2   37       1            0
# 4630          1         2018     1            3   27       1            0
# 4631          0         2012     0            3   30       1            1
# 4632          0         2015     0            3   33       1            1
#
#       ExperienceInCurrentDomain  LeaveOrNot
# 0                             0           0
# 1                             4           0
# 2                             3           0
# 3                             5           0
# 4                             4           0
# ...                         ...         ...
# 4628                          4           0
# 4629                          2           1
# 4630                          5           1
# 4631                          2           0
# 4632                          4           0
#
# [4633 rows x 9 columns]

# %%
# Unique elements
unique_identifier(data)
# Out:
# Education: [0 1 2], Length: 3
# JoiningYear: [2012 2017 2015 2013 2016 2014 2018], Length: 7
# City: [0 1 2], Length: 3
# PaymentTier: [3 2 1], Length: 3
# Age: [37 28 36 27 29 22 23 31 30 25 26 40 34 39 35 38 32 24 33 41], Length: 20
# Gender: [1 0], Length: 2
# EverBenched: [0 1], Length: 2
# ExperienceInCurrentDomain: [0 4 3 5 2 1 7 6], Length: 8
# LeaveOrNot: [0 1], Length: 2

# %% [markdown]
# # Data spliting

# %%
X = data.drop(['LeaveOrNot'], axis=1)
y = data['LeaveOrNot']

# %%
x_train, x_test, y_train, y_test = train_test_split(X,y, test_size=0.3)

# %% [markdown]
# ## Normalizing the dataset

# %%
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
type(x_train), type(x_test), type(y_train), type(y_test)
# Out:
# (numpy.ndarray,
#  numpy.ndarray,
#  pandas.core.series.Series,
#  pandas.core.series.Series)

# %%
y_train = y_train.to_numpy()
y_test = y_test.to_numpy()

# %%
type(x_train), type(x_test), type(y_train), type(y_test)
# Out:
# (numpy.ndarray, numpy.ndarray, numpy.ndarray, numpy.ndarray)

# %%
x_train = torch.from_numpy(x_train).type(torch.float)
y_train = torch.from_numpy(y_train).type(torch.float)
x_test = torch.from_numpy(x_test).type(torch.float)
y_test = torch.from_numpy(y_test).type(torch.float)

# %%
type(x_train), type(x_test), type(y_train), type(y_test)
# Out:
# (torch.Tensor, torch.Tensor, torch.Tensor, torch.Tensor)

# %% [markdown]
# # Dataloaders

# %%
batch_size = 32
train_loader = DataLoader(list(zip(x_train, y_train)), batch_size=batch_size, shuffle=True)
test_loader = DataLoader(list(zip(x_test, y_test)), batch_size=batch_size)

# %% [markdown]
# ## Accuracy function

# %%
def accuracy_fn(y_true, y_pred):
    correct = torch.eq(y_true, y_pred).sum().item()
    acc = (correct/len(y_pred)) * 100
    return acc

# %% [markdown]
# # Model building

# %%
class BinaryClassification(nn.Module):
    def __init__(self):
        super().__init__()
        self.layer_1 = nn.Linear(in_features=8, out_features=32)
        self.layer_2 = nn.Linear(in_features=32, out_features=32)
        self.layer_3 = nn.Linear(in_features=32, out_features=1)
        self.relu = nn.ReLU()

    def forward(self,x):
        return self.layer_3(self.relu(self.layer_2(self.relu(self.layer_1(x)))))

# %%
model = BinaryClassification().to(device)
model
# Out:
# BinaryClassification(
#   (layer_1): Linear(in_features=8, out_features=32, bias=True)
#   (layer_2): Linear(in_features=32, out_features=32, bias=True)
#   (layer_3): Linear(in_features=32, out_features=1, bias=True)
#   (relu): ReLU()
# )

# %%
summary(model)
# Out:
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ├─Linear: 1-1                            288
# ├─Linear: 1-2                            1,056
# ├─Linear: 1-3                            33
# ├─ReLU: 1-4                              --
# =================================================================
# Total params: 1,377
# Trainable params: 1,377
# Non-trainable params: 0
# =================================================================
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ├─Linear: 1-1                            288
# ├─Linear: 1-2                            1,056
# ├─Linear: 1-3                            33
# ├─ReLU: 1-4                              --
# =================================================================
# Total params: 1,377
# Trainable params: 1,377
# Non-trainable params: 0
# =================================================================

# %% [markdown]
# # Loss and optimizers

# %%
model = BinaryClassification()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
criterion = nn.BCEWithLogitsLoss()

# %%
epochs = 500
for epoch in range(epochs):
    model.train()
    for batch_x, batch_y in train_loader:
        optimizer.zero_grad()
        output = model(batch_x)
        loss = criterion(output.squeeze(), batch_y)
        loss.backward()
        optimizer.step()

    # Evaluate the model on the test set
    model.eval()
    test_predictions = []
    with torch.no_grad():
        for batch_x, batch_y in test_loader:
            output = model(batch_x)
            predictions = torch.round(torch.sigmoid(output))
            test_predictions.extend(predictions.tolist())
    
    accuracy = accuracy_score(y_test.tolist(), test_predictions)
    print(f"Epoch {epoch + 1}/{epochs}, Loss: {loss.item():.4f}, Accuracy: {accuracy * 100:.2f}%")
# Out:
# Epoch 1/500, Loss: 0.5754, Accuracy: 74.03%
# Epoch 2/500, Loss: 0.4835, Accuracy: 75.11%
# Epoch 3/500, Loss: 0.7241, Accuracy: 77.63%
# Epoch 4/500, Loss: 0.3560, Accuracy: 78.92%
# Epoch 5/500, Loss: 0.1314, Accuracy: 79.06%
# Epoch 6/500, Loss: 0.3533, Accuracy: 80.65%
# Epoch 7/500, Loss: 0.3286, Accuracy: 81.15%
# Epoch 8/500, Loss: 0.2609, Accuracy: 82.30%
# Epoch 9/500, Loss: 0.6553, Accuracy: 82.16%
# Epoch 10/500, Loss: 0.3592, Accuracy: 82.30%
# Epoch 11/500, Loss: 0.4747, Accuracy: 83.17%
# Epoch 12/500, Loss: 0.8056, Accuracy: 83.17%
# Epoch 13/500, Loss: 0.7115, Accuracy: 82.88%
# Epoch 14/500, Loss: 0.6114, Accuracy: 83.17%
# Epoch 15/500, Loss: 0.1266, Accuracy: 82.88%
# Epoch 16/500, Loss: 0.1074, Accuracy: 83.09%
# Epoch 17/500, Loss: 0.1972, Accuracy: 83.17%
# Epoch 18/500, Loss: 0.6837, Accuracy: 82.66%
# Epoch 19/500, Loss: 0.3072, Accuracy: 83.17%
# Epoch 20/500, Loss: 0.3345, Accuracy: 83.09%
# Epoch 21/500, Loss: 0.1490, Accuracy: 82.81%
# Epoch 22/500, Loss: 0.5412, Accuracy: 82.95%
# Epoch 23/500, Loss: 0.1817, Accuracy: 83.09%
# Epoch 24/500, Loss: 0.2633, Accuracy: 82.88%
# Epoch 25/500, Loss: 0.4198, Accuracy: 82.88%
# Epoch 26/500, Loss: 0.0861, Accuracy: 82.88%
# Epoch 27/500, Loss: 0.1197, Accuracy: 82.81%
# Epoch 28/500, Loss: 0.2774, Accuracy: 83.60%
# Epoch 29/500, Loss: 0.5934, Accuracy: 83.09%
# Epoch 30/500, Loss: 0.2442, Accuracy: 82.66%
# Epoch 31/500, Loss: 0.6275, Accuracy: 83.31%
# Epoch 32/500, Loss: 0.2727, Accuracy: 83.09%
# Epoch 33/500, Loss: 0.5850, Accuracy: 83.09%
# Epoch 34/500, Loss: 0.2538, Accuracy: 83.24%
# Epoch 35/500, Loss: 0.4531, Accuracy: 82.88%
# Epoch 36/500, Loss: 0.2056, Accuracy: 83.53%
# Epoch 37/500, Loss: 0.0745, Accuracy: 82.95%
# Epoch 38/500, Loss: 0.2263, Accuracy: 82.81%
# Epoch 39/500, Loss: 0.2064, Accuracy: 83.09%
# Epoch 40/500, Loss: 0.3712, Accuracy: 83.02%
# Epoch 41/500, Loss: 0.5115, Accuracy: 83.17%
# Epoch 42/500, Loss: 0.3801, Accuracy: 83.24%
# Epoch 43/500, Loss: 0.1209, Accuracy: 83.02%
# Epoch 44/500, Loss: 0.4591, Accuracy: 83.02%
# Epoch 45/500, Loss: 0.1984, Accuracy: 83.09%
# Epoch 46/500, Loss: 0.3146, Accuracy: 83.67%
# Epoch 47/500, Loss: 0.5458, Accuracy: 82.81%
# Epoch 48/500, Loss: 0.5923, Accuracy: 83.24%
# Epoch 49/500, Loss: 0.4043, Accuracy: 82.88%
# Epoch 50/500, Loss: 0.4362, Accuracy: 82.88%
# Epoch 51/500, Loss: 0.3868, Accuracy: 82.81%
# Epoch 52/500, Loss: 0.3265, Accuracy: 82.59%
# Epoch 53/500, Loss: 0.3803, Accuracy: 83.38%
# Epoch 54/500, Loss: 0.4805, Accuracy: 83.17%
# Epoch 55/500, Loss: 0.3438, Accuracy: 82.95%
# Epoch 56/500, Loss: 0.1624, Accuracy: 82.73%
# Epoch 57/500, Loss: 0.1475, Accuracy: 83.02%
# Epoch 58/500, Loss: 0.1200, Accuracy: 82.52%
# Epoch 59/500, Loss: 0.1027, Accuracy: 83.45%
# Epoch 60/500, Loss: 0.8457, Accuracy: 82.66%
# Epoch 61/500, Loss: 0.3236, Accuracy: 82.81%
# Epoch 62/500, Loss: 0.4807, Accuracy: 82.88%
# Epoch 63/500, Loss: 0.1898, Accuracy: 82.88%
# Epoch 64/500, Loss: 0.2621, Accuracy: 83.45%
# Epoch 65/500, Loss: 0.6044, Accuracy: 83.09%
# Epoch 66/500, Loss: 0.3752, Accuracy: 82.73%
# Epoch 67/500, Loss: 0.4035, Accuracy: 82.88%
# Epoch 68/500, Loss: 0.1061, Accuracy: 83.38%
# Epoch 69/500, Loss: 0.3658, Accuracy: 83.02%
# Epoch 70/500, Loss: 0.2111, Accuracy: 83.02%
# Epoch 71/500, Loss: 0.5841, Accuracy: 82.88%
# Epoch 72/500, Loss: 0.1981, Accuracy: 83.02%
# Epoch 73/500, Loss: 0.0852, Accuracy: 83.31%
# Epoch 74/500, Loss: 0.1216, Accuracy: 83.67%
# Epoch 75/500, Loss: 0.4347, Accuracy: 83.24%
# Epoch 76/500, Loss: 0.1005, Accuracy: 82.52%
# Epoch 77/500, Loss: 0.1662, Accuracy: 82.45%
# Epoch 78/500, Loss: 0.3607, Accuracy: 83.17%
# Epoch 79/500, Loss: 0.2364, Accuracy: 83.38%
# Epoch 80/500, Loss: 0.1323, Accuracy: 83.17%
# Epoch 81/500, Loss: 0.7660, Accuracy: 83.53%
# Epoch 82/500, Loss: 0.7411, Accuracy: 83.24%
# Epoch 83/500, Loss: 0.5119, Accuracy: 82.95%
# Epoch 84/500, Loss: 0.2676, Accuracy: 83.17%
# Epoch 85/500, Loss: 0.2452, Accuracy: 83.38%
# Epoch 86/500, Loss: 0.1772, Accuracy: 83.45%
# Epoch 87/500, Loss: 0.4443, Accuracy: 83.24%
# Epoch 88/500, Loss: 0.6634, Accuracy: 83.24%
# Epoch 89/500, Loss: 0.1924, Accuracy: 82.95%
# Epoch 90/500, Loss: 0.4572, Accuracy: 83.17%
# Epoch 91/500, Loss: 0.2493, Accuracy: 83.09%
# Epoch 92/500, Loss: 0.2850, Accuracy: 83.53%
# Epoch 93/500, Loss: 0.7267, Accuracy: 82.95%
# Epoch 94/500, Loss: 0.2252, Accuracy: 82.95%
# Epoch 95/500, Loss: 0.1418, Accuracy: 82.73%
# Epoch 96/500, Loss: 0.3899, Accuracy: 82.52%
# Epoch 97/500, Loss: 0.3463, Accuracy: 82.73%
# Epoch 98/500, Loss: 0.2876, Accuracy: 83.24%
# Epoch 99/500, Loss: 0.1488, Accuracy: 82.95%
# Epoch 100/500, Loss: 0.2874, Accuracy: 83.67%
# Epoch 101/500, Loss: 0.1723, Accuracy: 83.45%
# Epoch 102/500, Loss: 0.3218, Accuracy: 83.17%
# Epoch 103/500, Loss: 0.4124, Accuracy: 83.02%
# Epoch 104/500, Loss: 0.1422, Accuracy: 83.17%
# Epoch 105/500, Loss: 0.1652, Accuracy: 83.17%
# Epoch 106/500, Loss: 0.7216, Accuracy: 83.17%
# Epoch 107/500, Loss: 0.2676, Accuracy: 83.38%
# Epoch 108/500, Loss: 0.5784, Accuracy: 83.53%
# Epoch 109/500, Loss: 0.4348, Accuracy: 83.02%
# Epoch 110/500, Loss: 0.2260, Accuracy: 83.02%
# Epoch 111/500, Loss: 0.0626, Accuracy: 83.60%
# Epoch 112/500, Loss: 0.2313, Accuracy: 83.09%
# Epoch 113/500, Loss: 0.5181, Accuracy: 83.53%
# Epoch 114/500, Loss: 0.1971, Accuracy: 83.67%
# Epoch 115/500, Loss: 0.3635, Accuracy: 83.24%
# Epoch 116/500, Loss: 0.3709, Accuracy: 83.31%
# Epoch 117/500, Loss: 0.2496, Accuracy: 82.88%
# Epoch 118/500, Loss: 0.2309, Accuracy: 83.02%
# Epoch 119/500, Loss: 0.2735, Accuracy: 83.74%
# Epoch 120/500, Loss: 0.2137, Accuracy: 83.74%
# Epoch 121/500, Loss: 0.2923, Accuracy: 83.24%
# Epoch 122/500, Loss: 0.4405, Accuracy: 83.31%
# Epoch 123/500, Loss: 0.2332, Accuracy: 83.88%
# Epoch 124/500, Loss: 0.2671, Accuracy: 83.67%
# Epoch 125/500, Loss: 0.3618, Accuracy: 83.17%
# Epoch 126/500, Loss: 0.4689, Accuracy: 83.45%
# Epoch 127/500, Loss: 0.1566, Accuracy: 83.81%
# Epoch 128/500, Loss: 0.5130, Accuracy: 83.09%
# Epoch 129/500, Loss: 0.3494, Accuracy: 83.38%
# Epoch 130/500, Loss: 0.5142, Accuracy: 82.95%
# Epoch 131/500, Loss: 0.2294, Accuracy: 83.81%
# Epoch 132/500, Loss: 0.3240, Accuracy: 82.59%
# Epoch 133/500, Loss: 0.2249, Accuracy: 83.38%
# Epoch 134/500, Loss: 0.0953, Accuracy: 83.24%
# Epoch 135/500, Loss: 0.2635, Accuracy: 83.60%
# Epoch 136/500, Loss: 0.2987, Accuracy: 83.81%
# Epoch 137/500, Loss: 0.3341, Accuracy: 83.38%
# Epoch 138/500, Loss: 0.0664, Accuracy: 84.17%
# Epoch 139/500, Loss: 0.2639, Accuracy: 83.88%
# Epoch 140/500, Loss: 0.3508, Accuracy: 83.45%
# Epoch 141/500, Loss: 0.1174, Accuracy: 83.53%
# Epoch 142/500, Loss: 0.4268, Accuracy: 83.38%
# Epoch 143/500, Loss: 0.0709, Accuracy: 84.10%
# Epoch 144/500, Loss: 0.1839, Accuracy: 83.24%
# Epoch 145/500, Loss: 0.1806, Accuracy: 83.96%
# Epoch 146/500, Loss: 0.2439, Accuracy: 83.17%
# Epoch 147/500, Loss: 0.4947, Accuracy: 83.02%
# Epoch 148/500, Loss: 0.1061, Accuracy: 83.81%
# Epoch 149/500, Loss: 0.3581, Accuracy: 83.31%
# Epoch 150/500, Loss: 0.4894, Accuracy: 83.24%
# Epoch 151/500, Loss: 0.1052, Accuracy: 82.88%
# Epoch 152/500, Loss: 0.2461, Accuracy: 83.31%
# Epoch 153/500, Loss: 0.3213, Accuracy: 84.03%
# Epoch 154/500, Loss: 0.2979, Accuracy: 83.24%
# Epoch 155/500, Loss: 0.4976, Accuracy: 83.38%
# Epoch 156/500, Loss: 0.0990, Accuracy: 83.96%
# Epoch 157/500, Loss: 0.3108, Accuracy: 83.45%
# Epoch 158/500, Loss: 0.5900, Accuracy: 83.81%
# Epoch 159/500, Loss: 0.4991, Accuracy: 83.45%
# Epoch 160/500, Loss: 0.3845, Accuracy: 83.60%
# Epoch 161/500, Loss: 0.1126, Accuracy: 83.45%
# Epoch 162/500, Loss: 0.3094, Accuracy: 82.66%
# Epoch 163/500, Loss: 0.2987, Accuracy: 82.66%
# Epoch 164/500, Loss: 0.6779, Accuracy: 83.53%
# Epoch 165/500, Loss: 0.0843, Accuracy: 82.88%
# Epoch 166/500, Loss: 0.2285, Accuracy: 83.81%
# Epoch 167/500, Loss: 0.3288, Accuracy: 83.53%
# Epoch 168/500, Loss: 0.3683, Accuracy: 83.67%
# Epoch 169/500, Loss: 0.2131, Accuracy: 84.24%
# Epoch 170/500, Loss: 0.3130, Accuracy: 83.31%
# Epoch 171/500, Loss: 0.2898, Accuracy: 83.09%
# Epoch 172/500, Loss: 0.2834, Accuracy: 83.60%
# Epoch 173/500, Loss: 0.2515, Accuracy: 83.38%
# Epoch 174/500, Loss: 0.2812, Accuracy: 83.45%
# Epoch 175/500, Loss: 0.2215, Accuracy: 83.31%
# Epoch 176/500, Loss: 0.4411, Accuracy: 83.67%
# Epoch 177/500, Loss: 0.2551, Accuracy: 84.03%
# Epoch 178/500, Loss: 0.4139, Accuracy: 83.53%
# Epoch 179/500, Loss: 0.4585, Accuracy: 83.53%
# Epoch 180/500, Loss: 0.1404, Accuracy: 83.60%
# Epoch 181/500, Loss: 0.0829, Accuracy: 83.81%
# Epoch 182/500, Loss: 0.4356, Accuracy: 83.96%
# Epoch 183/500, Loss: 0.0890, Accuracy: 84.10%
# Epoch 184/500, Loss: 0.1237, Accuracy: 83.17%
# Epoch 185/500, Loss: 0.3938, Accuracy: 83.96%
# Epoch 186/500, Loss: 0.2285, Accuracy: 82.95%
# Epoch 187/500, Loss: 0.1568, Accuracy: 83.96%
# Epoch 188/500, Loss: 0.4362, Accuracy: 83.02%
# Epoch 189/500, Loss: 0.1556, Accuracy: 83.53%
# Epoch 190/500, Loss: 0.2135, Accuracy: 83.88%
# Epoch 191/500, Loss: 0.2664, Accuracy: 83.24%
# Epoch 192/500, Loss: 0.2282, Accuracy: 81.94%
# Epoch 193/500, Loss: 0.3612, Accuracy: 83.81%
# Epoch 194/500, Loss: 0.5137, Accuracy: 83.53%
# Epoch 195/500, Loss: 0.5036, Accuracy: 83.45%
# Epoch 196/500, Loss: 0.0691, Accuracy: 84.32%
# Epoch 197/500, Loss: 0.1094, Accuracy: 82.81%
# Epoch 198/500, Loss: 0.1066, Accuracy: 82.66%
# Epoch 199/500, Loss: 0.1279, Accuracy: 84.17%
# Epoch 200/500, Loss: 0.0977, Accuracy: 82.88%
# Epoch 201/500, Loss: 0.1800, Accuracy: 83.67%
# Epoch 202/500, Loss: 0.3267, Accuracy: 83.96%
# Epoch 203/500, Loss: 0.6441, Accuracy: 83.17%
# Epoch 204/500, Loss: 0.0930, Accuracy: 83.88%
# Epoch 205/500, Loss: 0.3188, Accuracy: 83.53%
# Epoch 206/500, Loss: 0.1175, Accuracy: 84.03%
# Epoch 207/500, Loss: 0.0751, Accuracy: 83.53%
# Epoch 208/500, Loss: 0.3113, Accuracy: 83.17%
# Epoch 209/500, Loss: 0.2065, Accuracy: 84.03%
# Epoch 210/500, Loss: 0.1638, Accuracy: 83.09%
# Epoch 211/500, Loss: 0.6411, Accuracy: 83.09%
# Epoch 212/500, Loss: 0.1924, Accuracy: 83.74%
# Epoch 213/500, Loss: 0.3682, Accuracy: 83.96%
# Epoch 214/500, Loss: 0.1159, Accuracy: 83.96%
# Epoch 215/500, Loss: 0.2053, Accuracy: 83.60%
# Epoch 216/500, Loss: 0.3685, Accuracy: 84.10%
# Epoch 217/500, Loss: 0.2753, Accuracy: 83.53%
# Epoch 218/500, Loss: 0.2475, Accuracy: 82.66%
# Epoch 219/500, Loss: 0.2816, Accuracy: 83.09%
# Epoch 220/500, Loss: 0.3467, Accuracy: 83.88%
# Epoch 221/500, Loss: 0.5261, Accuracy: 83.31%
# Epoch 222/500, Loss: 0.2139, Accuracy: 84.24%
# Epoch 223/500, Loss: 0.0690, Accuracy: 83.67%
# Epoch 224/500, Loss: 0.3145, Accuracy: 83.74%
# Epoch 225/500, Loss: 0.2492, Accuracy: 83.60%
# Epoch 226/500, Loss: 0.1854, Accuracy: 83.81%
# Epoch 227/500, Loss: 0.1127, Accuracy: 83.67%
# Epoch 228/500, Loss: 0.3826, Accuracy: 84.39%
# Epoch 229/500, Loss: 0.4314, Accuracy: 82.37%
# Epoch 230/500, Loss: 0.4954, Accuracy: 83.17%
# Epoch 231/500, Loss: 0.0893, Accuracy: 84.17%
# Epoch 232/500, Loss: 0.1442, Accuracy: 83.09%
# Epoch 233/500, Loss: 0.7130, Accuracy: 83.74%
# Epoch 234/500, Loss: 0.2279, Accuracy: 83.81%
# Epoch 235/500, Loss: 0.1916, Accuracy: 83.88%
# Epoch 236/500, Loss: 0.5406, Accuracy: 84.24%
# Epoch 237/500, Loss: 0.1269, Accuracy: 83.88%
# Epoch 238/500, Loss: 0.4708, Accuracy: 83.88%
# Epoch 239/500, Loss: 0.6302, Accuracy: 83.74%
# Epoch 240/500, Loss: 0.2154, Accuracy: 83.96%
# Epoch 241/500, Loss: 0.3525, Accuracy: 83.74%
# Epoch 242/500, Loss: 0.0778, Accuracy: 83.53%
# Epoch 243/500, Loss: 0.5921, Accuracy: 84.32%
# Epoch 244/500, Loss: 0.1226, Accuracy: 84.10%
# Epoch 245/500, Loss: 0.1743, Accuracy: 83.45%
# Epoch 246/500, Loss: 0.2169, Accuracy: 83.88%
# Epoch 247/500, Loss: 0.4035, Accuracy: 84.03%
# Epoch 248/500, Loss: 0.2426, Accuracy: 82.81%
# Epoch 249/500, Loss: 0.2344, Accuracy: 83.09%
# Epoch 250/500, Loss: 0.1249, Accuracy: 83.74%
# Epoch 251/500, Loss: 0.2373, Accuracy: 83.45%
# Epoch 252/500, Loss: 0.0831, Accuracy: 84.32%
# Epoch 253/500, Loss: 0.0935, Accuracy: 84.10%
# Epoch 254/500, Loss: 0.0615, Accuracy: 83.31%
# Epoch 255/500, Loss: 0.7149, Accuracy: 83.88%
# Epoch 256/500, Loss: 0.3468, Accuracy: 84.10%
# Epoch 257/500, Loss: 0.0889, Accuracy: 83.81%
# Epoch 258/500, Loss: 0.4713, Accuracy: 83.74%
# Epoch 259/500, Loss: 0.1049, Accuracy: 83.24%
# Epoch 260/500, Loss: 0.7263, Accuracy: 83.81%
# Epoch 261/500, Loss: 0.8744, Accuracy: 83.81%
# Epoch 262/500, Loss: 0.4297, Accuracy: 83.53%
# Epoch 263/500, Loss: 0.5430, Accuracy: 83.38%
# Epoch 264/500, Loss: 0.1206, Accuracy: 83.96%
# Epoch 265/500, Loss: 0.2713, Accuracy: 82.88%
# Epoch 266/500, Loss: 0.1861, Accuracy: 84.03%
# Epoch 267/500, Loss: 0.4449, Accuracy: 83.53%
# Epoch 268/500, Loss: 0.0438, Accuracy: 83.67%
# Epoch 269/500, Loss: 0.0413, Accuracy: 84.10%
# Epoch 270/500, Loss: 0.1176, Accuracy: 83.96%
# Epoch 271/500, Loss: 0.1128, Accuracy: 83.38%
# Epoch 272/500, Loss: 0.3523, Accuracy: 83.17%
# Epoch 273/500, Loss: 0.1641, Accuracy: 83.45%
# Epoch 274/500, Loss: 0.1372, Accuracy: 83.88%
# Epoch 275/500, Loss: 0.3016, Accuracy: 83.09%
# Epoch 276/500, Loss: 0.2836, Accuracy: 84.17%
# Epoch 277/500, Loss: 0.2756, Accuracy: 83.81%
# Epoch 278/500, Loss: 0.0973, Accuracy: 84.17%
# Epoch 279/500, Loss: 0.3678, Accuracy: 84.17%
# Epoch 280/500, Loss: 0.2068, Accuracy: 83.74%
# Epoch 281/500, Loss: 0.1236, Accuracy: 83.24%
# Epoch 282/500, Loss: 0.1366, Accuracy: 83.45%
# Epoch 283/500, Loss: 0.3562, Accuracy: 84.24%
# Epoch 284/500, Loss: 0.0759, Accuracy: 84.10%
# Epoch 285/500, Loss: 0.2007, Accuracy: 83.53%
# Epoch 286/500, Loss: 0.4344, Accuracy: 83.67%
# Epoch 287/500, Loss: 0.4004, Accuracy: 84.10%
# Epoch 288/500, Loss: 0.3035, Accuracy: 83.53%
# Epoch 289/500, Loss: 0.3821, Accuracy: 83.81%
# Epoch 290/500, Loss: 0.3097, Accuracy: 84.10%
# Epoch 291/500, Loss: 0.3156, Accuracy: 83.81%
# Epoch 292/500, Loss: 0.0415, Accuracy: 83.38%
# Epoch 293/500, Loss: 0.2224, Accuracy: 84.10%
# Epoch 294/500, Loss: 0.3790, Accuracy: 83.74%
# Epoch 295/500, Loss: 0.2831, Accuracy: 83.09%
# Epoch 296/500, Loss: 0.1206, Accuracy: 84.32%
# Epoch 297/500, Loss: 0.1061, Accuracy: 83.24%
# Epoch 298/500, Loss: 0.2675, Accuracy: 82.45%
# Epoch 299/500, Loss: 0.2744, Accuracy: 83.31%
# Epoch 300/500, Loss: 0.3100, Accuracy: 84.46%
# Epoch 301/500, Loss: 0.3787, Accuracy: 84.03%
# Epoch 302/500, Loss: 0.1446, Accuracy: 83.74%
# Epoch 303/500, Loss: 0.3876, Accuracy: 83.60%
# Epoch 304/500, Loss: 0.0880, Accuracy: 83.24%
# Epoch 305/500, Loss: 0.3392, Accuracy: 83.67%
# Epoch 306/500, Loss: 0.2780, Accuracy: 84.32%
# Epoch 307/500, Loss: 0.2538, Accuracy: 84.10%
# Epoch 308/500, Loss: 0.5859, Accuracy: 83.24%
# Epoch 309/500, Loss: 0.1022, Accuracy: 83.24%
# Epoch 310/500, Loss: 0.1156, Accuracy: 83.45%
# Epoch 311/500, Loss: 0.0936, Accuracy: 83.96%
# Epoch 312/500, Loss: 0.4269, Accuracy: 83.17%
# Epoch 313/500, Loss: 0.1743, Accuracy: 84.17%
# Epoch 314/500, Loss: 0.0765, Accuracy: 84.17%
# Epoch 315/500, Loss: 0.4715, Accuracy: 84.17%
# Epoch 316/500, Loss: 0.1710, Accuracy: 83.02%
# Epoch 317/500, Loss: 0.2114, Accuracy: 83.67%
# Epoch 318/500, Loss: 0.1615, Accuracy: 84.03%
# Epoch 319/500, Loss: 0.2408, Accuracy: 83.02%
# Epoch 320/500, Loss: 0.0724, Accuracy: 83.24%
# Epoch 321/500, Loss: 0.0920, Accuracy: 83.67%
# Epoch 322/500, Loss: 0.1450, Accuracy: 83.67%
# Epoch 323/500, Loss: 0.1801, Accuracy: 84.17%
# Epoch 324/500, Loss: 0.4664, Accuracy: 83.24%
# Epoch 325/500, Loss: 0.2947, Accuracy: 83.17%
# Epoch 326/500, Loss: 0.2201, Accuracy: 83.81%
# Epoch 327/500, Loss: 0.1400, Accuracy: 83.67%
# Epoch 328/500, Loss: 0.1431, Accuracy: 83.24%
# Epoch 329/500, Loss: 0.2332, Accuracy: 84.17%
# Epoch 330/500, Loss: 0.2103, Accuracy: 84.24%
# Epoch 331/500, Loss: 0.2876, Accuracy: 83.88%
# Epoch 332/500, Loss: 0.1731, Accuracy: 83.38%
# Epoch 333/500, Loss: 0.1875, Accuracy: 83.02%
# Epoch 334/500, Loss: 0.6449, Accuracy: 83.38%
# Epoch 335/500, Loss: 0.1694, Accuracy: 83.88%
# Epoch 336/500, Loss: 0.4219, Accuracy: 83.67%
# Epoch 337/500, Loss: 0.2763, Accuracy: 83.02%
# Epoch 338/500, Loss: 0.1299, Accuracy: 83.17%
# Epoch 339/500, Loss: 0.1734, Accuracy: 83.31%
# Epoch 340/500, Loss: 0.3237, Accuracy: 83.02%
# Epoch 341/500, Loss: 0.1319, Accuracy: 83.67%
# Epoch 342/500, Loss: 0.3163, Accuracy: 84.03%
# Epoch 343/500, Loss: 0.3338, Accuracy: 83.45%
# Epoch 344/500, Loss: 0.0783, Accuracy: 83.45%
# Epoch 345/500, Loss: 0.1165, Accuracy: 83.09%
# Epoch 346/500, Loss: 0.8088, Accuracy: 83.24%
# Epoch 347/500, Loss: 0.1010, Accuracy: 83.24%
# Epoch 348/500, Loss: 0.1617, Accuracy: 83.45%
# Epoch 349/500, Loss: 0.1261, Accuracy: 83.09%
# Epoch 350/500, Loss: 0.0554, Accuracy: 83.60%
# Epoch 351/500, Loss: 0.1641, Accuracy: 83.38%
# Epoch 352/500, Loss: 0.1788, Accuracy: 83.88%
# Epoch 353/500, Loss: 0.1134, Accuracy: 83.02%
# Epoch 354/500, Loss: 0.3106, Accuracy: 83.45%
# Epoch 355/500, Loss: 0.3602, Accuracy: 83.31%
# Epoch 356/500, Loss: 0.1142, Accuracy: 83.45%
# Epoch 357/500, Loss: 0.3866, Accuracy: 83.60%
# Epoch 358/500, Loss: 0.3877, Accuracy: 83.60%
# Epoch 359/500, Loss: 0.1132, Accuracy: 83.24%
# Epoch 360/500, Loss: 0.1279, Accuracy: 83.09%
# Epoch 361/500, Loss: 0.1879, Accuracy: 82.73%
# Epoch 362/500, Loss: 0.2927, Accuracy: 83.45%
# Epoch 363/500, Loss: 0.2946, Accuracy: 83.31%
# Epoch 364/500, Loss: 0.2623, Accuracy: 83.81%
# Epoch 365/500, Loss: 0.3218, Accuracy: 83.53%
# Epoch 366/500, Loss: 0.0813, Accuracy: 83.67%
# Epoch 367/500, Loss: 0.4054, Accuracy: 82.01%
# Epoch 368/500, Loss: 0.1858, Accuracy: 83.17%
# Epoch 369/500, Loss: 0.2620, Accuracy: 83.96%
# Epoch 370/500, Loss: 0.1395, Accuracy: 83.45%
# Epoch 371/500, Loss: 0.4870, Accuracy: 83.96%
# Epoch 372/500, Loss: 0.2187, Accuracy: 83.17%
# Epoch 373/500, Loss: 0.2372, Accuracy: 82.59%
# Epoch 374/500, Loss: 0.1230, Accuracy: 83.60%
# Epoch 375/500, Loss: 0.4280, Accuracy: 83.53%
# Epoch 376/500, Loss: 0.2899, Accuracy: 83.09%
# Epoch 377/500, Loss: 0.1610, Accuracy: 83.45%
# Epoch 378/500, Loss: 0.0735, Accuracy: 83.74%
# Epoch 379/500, Loss: 0.2662, Accuracy: 82.45%
# Epoch 380/500, Loss: 0.2429, Accuracy: 82.95%
# Epoch 381/500, Loss: 0.3224, Accuracy: 83.74%
# Epoch 382/500, Loss: 0.7596, Accuracy: 83.17%
# Epoch 383/500, Loss: 0.2528, Accuracy: 83.88%
# Epoch 384/500, Loss: 0.0924, Accuracy: 83.74%
# Epoch 385/500, Loss: 0.3702, Accuracy: 83.24%
# Epoch 386/500, Loss: 0.1700, Accuracy: 82.81%
# Epoch 387/500, Loss: 0.3893, Accuracy: 82.81%
# Epoch 388/500, Loss: 0.2285, Accuracy: 83.74%
# Epoch 389/500, Loss: 0.1508, Accuracy: 83.17%
# Epoch 390/500, Loss: 0.2419, Accuracy: 83.45%
# Epoch 391/500, Loss: 0.1982, Accuracy: 83.81%
# Epoch 392/500, Loss: 0.4716, Accuracy: 82.95%
# Epoch 393/500, Loss: 0.3565, Accuracy: 81.51%
# Epoch 394/500, Loss: 0.2243, Accuracy: 83.53%
# Epoch 395/500, Loss: 0.1087, Accuracy: 83.53%
# Epoch 396/500, Loss: 0.0796, Accuracy: 82.59%
# Epoch 397/500, Loss: 0.4376, Accuracy: 83.67%
# Epoch 398/500, Loss: 0.3226, Accuracy: 82.37%
# Epoch 399/500, Loss: 0.1717, Accuracy: 83.17%
# Epoch 400/500, Loss: 0.2412, Accuracy: 83.38%
# Epoch 401/500, Loss: 0.2805, Accuracy: 83.17%
# Epoch 402/500, Loss: 0.3137, Accuracy: 82.66%
# Epoch 403/500, Loss: 0.1821, Accuracy: 82.73%
# Epoch 404/500, Loss: 0.3817, Accuracy: 82.81%
# Epoch 405/500, Loss: 0.0528, Accuracy: 83.17%
# Epoch 406/500, Loss: 0.1744, Accuracy: 82.45%
# Epoch 407/500, Loss: 0.4651, Accuracy: 82.95%
# Epoch 408/500, Loss: 0.0764, Accuracy: 83.02%
# Epoch 409/500, Loss: 0.0875, Accuracy: 83.67%
# Epoch 410/500, Loss: 0.4950, Accuracy: 83.31%
# Epoch 411/500, Loss: 0.4167, Accuracy: 82.30%
# Epoch 412/500, Loss: 0.1606, Accuracy: 83.24%
# Epoch 413/500, Loss: 0.2958, Accuracy: 83.02%
# Epoch 414/500, Loss: 0.7840, Accuracy: 83.38%
# Epoch 415/500, Loss: 0.1345, Accuracy: 83.81%
# Epoch 416/500, Loss: 0.1506, Accuracy: 82.59%
# Epoch 417/500, Loss: 0.2215, Accuracy: 83.38%
# Epoch 418/500, Loss: 0.1845, Accuracy: 83.53%
# Epoch 419/500, Loss: 0.2316, Accuracy: 83.17%
# Epoch 420/500, Loss: 0.0916, Accuracy: 81.73%
# Epoch 421/500, Loss: 0.2818, Accuracy: 82.16%
# Epoch 422/500, Loss: 0.6806, Accuracy: 83.02%
# Epoch 423/500, Loss: 0.1459, Accuracy: 82.52%
# Epoch 424/500, Loss: 0.1555, Accuracy: 83.17%
# Epoch 425/500, Loss: 0.2575, Accuracy: 83.17%
# Epoch 426/500, Loss: 0.1716, Accuracy: 83.31%
# Epoch 427/500, Loss: 0.0965, Accuracy: 83.09%
# Epoch 428/500, Loss: 0.1057, Accuracy: 82.73%
# Epoch 429/500, Loss: 0.2008, Accuracy: 82.37%
# Epoch 430/500, Loss: 0.1193, Accuracy: 83.67%
# Epoch 431/500, Loss: 0.3224, Accuracy: 83.45%
# Epoch 432/500, Loss: 0.1311, Accuracy: 83.45%
# Epoch 433/500, Loss: 0.4462, Accuracy: 82.88%
# Epoch 434/500, Loss: 0.4617, Accuracy: 81.80%
# Epoch 435/500, Loss: 0.1017, Accuracy: 83.60%
# Epoch 436/500, Loss: 0.1088, Accuracy: 81.51%
# Epoch 437/500, Loss: 0.3336, Accuracy: 83.60%
# Epoch 438/500, Loss: 0.2515, Accuracy: 82.52%
# Epoch 439/500, Loss: 0.1826, Accuracy: 83.60%
# Epoch 440/500, Loss: 0.1934, Accuracy: 83.88%
# Epoch 441/500, Loss: 0.3186, Accuracy: 82.81%
# Epoch 442/500, Loss: 0.3946, Accuracy: 83.81%
# Epoch 443/500, Loss: 0.1823, Accuracy: 82.95%
# Epoch 444/500, Loss: 0.4326, Accuracy: 82.16%
# Epoch 445/500, Loss: 0.2406, Accuracy: 83.53%
# Epoch 446/500, Loss: 0.0776, Accuracy: 83.53%
# Epoch 447/500, Loss: 0.2469, Accuracy: 82.88%
# Epoch 448/500, Loss: 0.4226, Accuracy: 82.59%
# Epoch 449/500, Loss: 0.1753, Accuracy: 83.09%
# Epoch 450/500, Loss: 0.0625, Accuracy: 83.24%
# Epoch 451/500, Loss: 0.2042, Accuracy: 83.45%
# Epoch 452/500, Loss: 0.2951, Accuracy: 82.66%
# Epoch 453/500, Loss: 0.3035, Accuracy: 82.66%
# Epoch 454/500, Loss: 0.0866, Accuracy: 83.09%
# Epoch 455/500, Loss: 0.2289, Accuracy: 83.17%
# Epoch 456/500, Loss: 0.1867, Accuracy: 83.09%
# Epoch 457/500, Loss: 0.1759, Accuracy: 82.95%
# Epoch 458/500, Loss: 0.1070, Accuracy: 81.80%
# Epoch 459/500, Loss: 0.2842, Accuracy: 82.59%
# Epoch 460/500, Loss: 0.5403, Accuracy: 82.52%
# Epoch 461/500, Loss: 0.2570, Accuracy: 82.73%
# Epoch 462/500, Loss: 0.3041, Accuracy: 82.30%
# Epoch 463/500, Loss: 0.3063, Accuracy: 82.88%
# Epoch 464/500, Loss: 0.3920, Accuracy: 83.09%
# Epoch 465/500, Loss: 0.3671, Accuracy: 83.53%
# Epoch 466/500, Loss: 0.2492, Accuracy: 83.17%
# Epoch 467/500, Loss: 0.0536, Accuracy: 83.02%
# Epoch 468/500, Loss: 0.3486, Accuracy: 83.24%
# Epoch 469/500, Loss: 0.3774, Accuracy: 81.87%
# Epoch 470/500, Loss: 0.3003, Accuracy: 83.45%
# Epoch 471/500, Loss: 0.0982, Accuracy: 83.60%
# Epoch 472/500, Loss: 0.8821, Accuracy: 83.60%
# Epoch 473/500, Loss: 0.1878, Accuracy: 82.59%
# Epoch 474/500, Loss: 0.2167, Accuracy: 81.80%
# Epoch 475/500, Loss: 0.2046, Accuracy: 82.16%
# Epoch 476/500, Loss: 0.1339, Accuracy: 83.09%
# Epoch 477/500, Loss: 0.0626, Accuracy: 81.51%
# Epoch 478/500, Loss: 0.1200, Accuracy: 82.59%
# Epoch 479/500, Loss: 0.2279, Accuracy: 83.17%
# Epoch 480/500, Loss: 0.2513, Accuracy: 83.31%
# Epoch 481/500, Loss: 0.0621, Accuracy: 82.66%
# Epoch 482/500, Loss: 0.1156, Accuracy: 82.88%
# Epoch 483/500, Loss: 0.1994, Accuracy: 82.45%
# Epoch 484/500, Loss: 0.4615, Accuracy: 83.09%
# Epoch 485/500, Loss: 0.3985, Accuracy: 83.02%
# Epoch 486/500, Loss: 0.3908, Accuracy: 83.17%
# Epoch 487/500, Loss: 0.3166, Accuracy: 83.09%
# Epoch 488/500, Loss: 0.2405, Accuracy: 82.88%
# Epoch 489/500, Loss: 0.1363, Accuracy: 82.88%
# Epoch 490/500, Loss: 0.2160, Accuracy: 82.37%
# Epoch 491/500, Loss: 0.0982, Accuracy: 82.45%
# Epoch 492/500, Loss: 0.4518, Accuracy: 82.73%
# Epoch 493/500, Loss: 0.2807, Accuracy: 83.31%
# Epoch 494/500, Loss: 0.2454, Accuracy: 83.09%
# Epoch 495/500, Loss: 0.4555, Accuracy: 83.31%
# Epoch 496/500, Loss: 0.2750, Accuracy: 81.80%
# Epoch 497/500, Loss: 0.1128, Accuracy: 83.09%
# Epoch 498/500, Loss: 0.4863, Accuracy: 83.31%
# Epoch 499/500, Loss: 0.7325, Accuracy: 82.73%
# Epoch 500/500, Loss: 0.0277, Accuracy: 83.09%
